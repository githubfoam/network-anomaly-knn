# %%
# 1. Setup
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from src.data_loader import load_unsw_nb15

# %%
# 2. Load data from Kaggle
df = load_unsw_nb15()
df.head()

# %%
# 3. Basic EDA
print(df.info())
print(df.describe())

# %%
# 4. Feature Distribution
plt.figure(figsize=(12, 6))
sns.histplot(df['srcip'], bins=50)
plt.title("Source IP Distribution")
plt.show()

# %%
# 5. Train/Test example
from src.model import train_knn, evaluate_model
X_train, X_test, y_train, y_test = ...
model = train_knn(X_train, y_train)
evaluate_model(model, X_test, y_test)
